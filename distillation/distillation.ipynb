# %%
import pandas as pd

# %%
train_ds = pd.read_csv("../data/train_data.csv")
val_ds = pd.read_csv("../data/val_data.csv")
test_ds = pd.read_csv("../data/test_data.csv")
